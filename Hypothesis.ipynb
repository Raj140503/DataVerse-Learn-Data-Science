# %% [markdown]
# **Question -** A company the manufacturing RAM chips claims the defective rate of the population is 5%. Let P denote the true defective probablity. we want ti test if :
#
# *   𝘏o : 𝑷 = 0.05
# *   𝘏1 : 𝑷 > 0.05
#
# We are going to use a sample of 100 chips from the production to test.
#
# Let X denote the number of defective in the sample of 100.
# Reject 𝐻o if 𝘟 ≥ 10 (chosen “arbitrarily” in this case).
# 𝘟 is called the test statistic.
#
# ![image.png](data:image/png;base64,...)
#
# ### Types of Error -
#
# **Type I Error :**
#
# 1. Because we are making a decision based on a finite sample, there is a possibility that we will make mistakes. The possible outcomes are:
#
# |                  | 𝐻0 is true | 𝐻1  is true |
# |------------------|----------------------------|----------------------------|
# | **Do not reject 𝐻0** | Correct decision | Type II error             |
# | **Reject 𝐻0**        | Type I error     | Correct decision          |
#
#
# 2. **Definition -**
#
# The acceptance of 𝐻1 when 𝐻0 is true is called a Type I error.
# The probability of committing a type I error is called the level
# of significance and is denoted by α.
#
# 3. **Example -**
# Convicting the defendant when he is innocent!
#
#
# 4. The lower significance level α, the less likely we are to commit
# a type I error. Generally, we would like small values of α;
# typically, 0.05 or smaller.
#
# 5. **Case Study -**
# $$
# \alpha = \Pr(\text{Type I error}) = \Pr(\text{reject } H_0 \text{ when } H_0 \text{ is true})
# $$
# $$
# = \Pr(X \geq 10 \text{ when } p = 0.05)
# $$
# $$
# = \sum_{x=10}^{100} b(x; n=100, p=0.05), \quad \text{binomial distribution}
# $$
# $$
# = \sum_{x=10}^{100} \binom{100}{x} 0.05^x 0.95^{100-x} = 0.0282
# $$
# $$
# \text{So, the level of significance is } \alpha = 0.0282.
# $$
#
#
# **Type II Error :**
#
# 1. **Definition -**
# Failure to reject 𝐻0 when 𝐻1 is true is called a Type II error.
# The probability of committing a type II error is denoted by β.
#
# 2. **Case Study 1-**
#
# We cannot compute  \beta for  𝐻0 : p > 0.05 because the true p is unknown
# However, we can compute it for testing
#
# 𝐻0 : p = 0.05 , against the alternative hypothesis that
#
# 𝐻1 : p = 0.1, for instance.
# $$
# \beta = \Pr(\text{Type II error}) = \Pr(\text{reject } H_1 \text{ when } H_1 \text{ is true})
# $$
# $$
# = \Pr(X < 10 \text{ when } p = 0.1)
# $$
# $$
# = \sum_{x=0}^{9} b(x; n = 100, p = 0.1) = 0.4513
# $$
#
# 3. **Case Study 2 -**
# What is the probability of a type II error if p = 0.15?
# $$
# \beta = \Pr(\text{Type II error})
# $$
# $$
# = \Pr(X < 10 \text{ when } p = 0.15)
# $$
# $$
# = \sum_{x=0}^{9} b(x; n = 100, p = 0.15) = 0.0551
# $$
#
# ### Approximating the binomial distribution using the normal distribution.
#
# **1. Theorem -**
# If 𝑋 is a binomial random variable with n trials and probability
# of success of each trial 𝑝, then the limiting form of the
# distribution of
#
# ![image.png](data:image/png;base64,...)
#
# is the standard normal distribution.
#
# This approximation is good when 𝑛 is large and 𝑝 is not extremely close to 0 or 1.
#
# ### Visual interpretation with normal approximation.
#
# ![image.png](data:image/png;base64,...)
#
#
# **Properties of hypothesis testing -**
# 1. α and β are related; decreasing one generally increases
# the other.
# 2. α can be set to a desired value by adjusting the critical
# value. Typically, α is set at 0.05 or 0.01.
# 3. Increasing n decreases both α and β.
# 4. β decreases as the distance between the true value and
# hypothesized value 𝐻1 increases
#
#
# ### One tailed vs Two tailed
#
# **1. One tailed -**
# In our examples so far we have considered:
#   * 𝐻0: θ = θ0
#   * 𝐻1: θ > θ0.
# This is a one-tailed test with the critical region in the right-tail
# of the test statistic X.
#
# ![image.png](data:image/png;base64,...)
#
# 2. Another one-tailed test could have the form,
#   * 𝐻0: θ = θ0
#   * 𝐻1: θ < θ0,
# in which the critical region is in the left-tail.
#
# ![image.png](data:image/png;base64,...)
#
# **Two-tailed -**
# In a two-tailed test check for differences:
#   * 𝐻0: θ = θ0
#   * 𝐻1: $θ \neq θ0$,
#
# ![image.png](data:image/png;base64,...)
#
# **Example -**
# Consider a production line of resistors that are supposed to be
# 100 Ohms. Assume σ = 8. So, the hypotheses are:
# * H0: µ = 100
# * H1: µ 6= 100,
# Let X be the sample mean for a sample of size n = 100.
#
# ![image.png](data:image/png;base64,...)
#
# In this case the test statistic is the sample mean because this
# is a continuous random variable.
#
#
# ![image.png](data:image/png;base64,...)
#
# We know the sampling distribution of X¯ is a normal distribution with mean µ and standard deviation σ/√n = 0.8 due to the central limit theorem.
#
#
# Therefore we can compute the probability of a type I error as :
# $$
# \alpha = \Pr(X < 98 \text{ when } \mu = 100) + \Pr(X > 102 \text{ when } \mu = 100)
# $$
# $$
# = \Pr \left( Z < \frac{98 - 100}{8/\sqrt{100}} \right) + \Pr \left( Z > \frac{102 - 100}{8/\sqrt{100}} \right)
# $$
# $$
# = \Pr(Z < -2.5) + \Pr(Z > 2.5)
# $$
# $$
# = 2 \times \Pr(Z < -2.5) = 2 \times 0.0062 = 0.0124.
# $$
#
# ### Tests concerning sample mean
# From confidence intervals we know that -
#
# ![image.png](data:image/png;base64,...)
#
#
# Therefore, to design a test at the level of significance α we
# choose the critical values a and b as -
#
# ![image.png](data:image/png;base64,...)
#
# then we collect the sample, compute the sample mean X and
# reject 𝐻0 if X < a or X > b.
#
# **Steps in hypothesis testing -**
# 1. State the null and alternate hypothesis
# 2. Choose a significance level α
# 3. Choose the test statistic and establish the critical region
# 4. Collect the sample and compute the test statistic. If the test statistic is in the critical region, reject 𝐻0. Otherwise, do not reject 𝐻0.
#
# ### Tests concerning sample mean (variance known)
#
# **Example -**
#
# **Que -**A batch of 100 resistors have an average of 102 Ohms.
# Assuming a population standard deviation of 8 Ohms, test
# whether the population mean is 100 Ohms at a significance
# level of α = 0.05.
#
# **Ans -**
#
# Step 1:
#   * H0 : µ = 100
#   * H1 : µ 6= 100,
#
# Note: Unless stated otherwise, we use a two-tailed test.
#
# Step 2: α = 0.05
#
# Step 3: In this case, the test statistic is specified by the
# problem to be the sample mean X.
#
# Reject H0 if X < a or X > b, with
#
# ![image.png](data:image/png;base64,...)
#
# Step 4: We are told that the test statistic on a sample is
# X = 102 > b. Therefore, reject 𝐻0.
#
# ![WhatsApp Image 2024-07-15 at 10.28.58_36d00942.jpg](data:image/jpeg;base64,...)
#
# **Example 2 -**
#
# **Que -** A quality control engineer finds that a sample of 100 light
# bulbs had an average life-time of 470 hours. Assuming a
# population standard deviation of σ = 25 hours, test whether
# the population mean is 480 hours vs. the alternative
# hypothesis µ < 480 at a significance level of α = 0.05.
#
# **Ans -**
#
# Step 1:
# * 𝐻0 : µ = 480
# * 𝐻1 : µ < 480,
#
# Step 2: α = 0.05
#
# Step 3: The test statistic is the sample mean X. Reject 𝐻0 if
#
# ![image.png](data:image/png;base64,...)
#
# Step 4: Since X = 470 < 475.9, we reject 𝐻0.
#
#
# **Example 3 -**
#
# **Que -** It is claimed that a vacuum cleaner expends 46 kWh per year.
# A random sample of 12 homes indicates that vacuum cleaners
# expend an average of 42 kWh per year with (sample) standard
# deviation 11.9 kWh. At a 0.05 level of significance, does this
# suggest that, on average, vacuum cleaner expend less than
# 46 kWh per year? Assume the population to be normally
# distributed.
#
# **Ans -**
#
# Step 1:
# * H0 : µ = 46 kWh
# * H1 : µ < 46 kWh,
#
# Step 2: α = 0.05
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Example
#
# 1. A school dentist regularly inspects the teeth of children in their last year at primary school. She keeps records of the number of decayed teeth for these 11-year old children in her area. Over a number of years, she has found that the number of decayed teeth was approx normally distributed with mean 3.4 and standard deviation 2.1. She visits just one middle school in her rounds. the class of 28 12-years old at that school have a mean of 3.0 decayed teeth. Is there are any significant difference between this group and her usual 11-year-old Patients ?
#
# Solution -
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# 2. A Manufacturer claims that average life of their electric light bulbs is 2000 hrs. A random sample of 64 bulbs is testedand the life, x, in hours recorded. The results are obtained are as follows :
#
# $\epsilon$x = 127.808    $\epsilon$(x`-x)^2 = 9694.6
#
# Is there any sufficient evidence, at the 1% level, that the manufacturer is over estimating the length of the lifeof the light bulbs ?
#
# Solution -
#
# ![image.png](data:image/png;base64,...)
#
#
#
# **Observed Value is greater than Critical value**
#
# ![image.png](data:image/png;base64,...)
#
#
# **Observed value less than critical value**
#
# ![image.png](data:image/png;base64,...)
#
# **Observed value is equal to critical value**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### T test -
# Test for single Mean (n<30)
# 1. Form the null hypothesis
#  Ho: µ=µo
# (i.e) There is no significance difference between the sample mean and the population
# mean ie., µ=µo
# 2. Form the Alternate hypothesis
#
#  H1 : µ≠µo (or µ>µo or µ<µo)
#
#   ie., There is significance difference between the sample mean and the population
# mean
# 3. Level of Significance
# The level may be fixed at either 5% or 1%
# 4. Test statistic -
# $$
# t_{cal} = \left| \frac{\bar{x} - \mu}{\frac{s}{\sqrt{n}}} \right| \sim t_{(n-1) \ \text{d.f}}
# $$
#
# Where
#
# $$
# \bar{x} = \frac{\sum x_i}{n}
# $$
#
# Where
#
# $$
# s = \sqrt{\frac{\sum x^2 - \left(\sum x\right)^2 / n}{n - 1}}
# $$
#
# 5. Find the table value
#
#  ttab=t(0.05,(n-1) d.f
#
#   1. Inference
#
#     If tcal<ttab
#
# * (i) We accept the null hypothesis H0
# * (ii) There is no significant difference (or) if tcal> ttab
# * (i)We reject the null hypothesis H0 (ie) we accept the alternative hypothesis
# * (ii)There is significant difference between the sample mean and the population mean.
#
# **Note*
# F-test is used to test the equality of two means
#
# $$
# F = \frac{S_1^2}{S_2^2} \sim F_{(n_1 - 1, n_2 - 1) \ \text{d.f}} \quad \text{if} \ S_1^2 > S_2^2
# $$
#
# ![image.png](data:image/png;base64,...)
#
# $$
# F = \frac{S_2^2}{S_1^2} \sim F_{(n_2 - 1, n_1 - 1) \ \text{d.f}} \quad \text{if} \ S_2^2 > S_1^2
# $$
#
#
# Inference
#
# Fcal<Ftab.
#
# We accept the null hypothesis H0.(i.e) the variances are equal.
#
# Test Statistic
#
# $$
# t = \frac{|\bar{x}_1 - \bar{x}2|}{\sqrt{\frac{1}{n_1} + \frac{1}{n_2}}} \cdot t{(n_1+n_2-2), d.f}
# $$
# Where
# $$
# s^2 = \frac{\left[\sum x_1^2 - \frac{(\sum x_1)^2}{n1}\right] + \left[\sum x_2^2 - \frac{(\sum x_2)^2}{n2}\right]}{n_1 + n_2 - 2}
# $$
#
# **Variances are equal -**
# a. When the samples have unequal variances and equal number of observations(n1=n2), the test statistic is
#
# $$
# t = \frac{|\bar{x}_1 - \bar{x}2|}{S_p\sqrt{\frac{1}{n_1} + \frac{1}{n_2}}} \sim t{(\frac{n_1+n_2}{2}-1),d.f}
# $$
#
# b. When the samples have unequal variances and unequal number of observations
# (n1≠n2), the test statistic is
#
# $$
# t = \frac{(\bar{x}_1 - \bar{x}_2)}{\sqrt{\frac{S_1^2}{n_1} + \frac{S_2^2}{n_2}}}
# $$
#
# This statistic follows neither t nor normal distribution but it follows Behrens-Fisher test. The Behrens – Fisher test is laborious one. An alternative simple method has been suggested by Cochran & Cox. In this method the critical value of t is altered as tw (i.e) weighted t test.
#
# $$
# t_w = \frac{t_1\left(\frac{S_1^2}{n1}\right) + t_2\left(\frac{S_2^2}{n2}\right)}{\frac{S_1^2}{n1} + \frac{S_2^2}{n2}}
# $$
#
# $$
# \text{Where } t_1=t_{(n1-1)} \text{ d.f}
# $$
# $$
# t_2=t_{(n2-1)} \text{ d.f}
# $$

# %% [markdown]
# ### One-Sample T-Test

# %% [markdown]
# **Question** - For instance, consider a hypothetical scenario where we have test scores from a sample of students and we want to compare the mean of these scores with a hypothesized population mean. Let’s assume the population mean is 70.

# %%
import numpy as np
from scipy import stats

# %%
student_scores = np.array([72, 89, 65, 73, 79, 84, 63, 76, 85, 75])

# %% [markdown]
# The ```ttest_1samp()``` function in the code above performs a one-sample t-test and returns two values: the t-statistic and the p-value.

# %%
mu = 70

t_stat, p_value = stats.ttest_1samp(student_scores, mu)
print("T Statistics :", t_stat)
print("P_Value :", p_value)
# Out:
# T Statistics : 2.2894683580127317
# P_Value : 0.047816221110566944

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. The mean of the sample is significantly different from the hypothesized population mean.")
else:
    print("Fail to reject the null hypothesis. The mean of the sample is not significantly different from the hypothesized population mean.")
# Out:
# Reject the null hypothesis. The mean of the sample is significantly different from the hypothesized population mean.

# %% [markdown]
# ### Two-Sample T-Test

# %%
import seaborn as sns
import numpy as np
from scipy import stats

# %%
data = sns.load_dataset('iris')

# %%
setosa = data[data['species'] == 'setosa']
versicolor = data[data['species'] == 'versicolor']

# %%
setosa_petal_length = setosa['petal_length']
versicolor_petal_length = versicolor['petal_length']

# %%
t_stat, p_value = stats.ttest_ind(setosa_petal_length, versicolor_petal_length)
print("T Statistics :", t_stat)
print("P_Value :", p_value)
# Out:
# T Statistics : -39.492719391538095
# P_Value : 5.404910513441677e-62

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in petal lengths between setosa and versicolor plants.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in petal lengths between setosa and versicolor plants.")
# Out:
# Reject the null hypothesis. There is a significant difference in petal lengths between setosa and versicolor plants.

# %% [markdown]
# **For Petal width**

# %%
setosa_petal_width = setosa['petal_width']
versicolor_petal_width = versicolor['petal_width']

# %%
t_stat, p_value = stats.ttest_ind(setosa_petal_width, versicolor_petal_width)
print("T Statistics :", t_stat)
print("P_Value :", p_value)
# Out:
# T Statistics : -34.08034154357719
# P_Value : 3.831095388248162e-56

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in petal widths between setosa and versicolor plants.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in petal widths between setosa and versicolor plants.")
# Out:
# Reject the null hypothesis. There is a significant difference in petal widths between setosa and versicolor plants.

# %% [markdown]
# **Column - Virginica**

# %%
setosa = data[data['species'] == 'setosa']
virginica = data[data['species'] == 'virginica']

# %%
setosa_petal_length = setosa['petal_length']
virginica_petal_length = virginica['petal_length']

# %%
t_stat, p_value = stats.ttest_ind(setosa_petal_length, virginica_petal_length)
print("T Statistics :", t_stat)
print("P_Value :", p_value)
# Out:
# T Statistics : -49.98618625709594
# P_Value : 1.5048006992427275e-71

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in petal lengths between setosa and versicolor plants.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in petal lengths between setosa and versicolor plants.")
# Out:
# Reject the null hypothesis. There is a significant difference in petal lengths between setosa and versicolor plants.

# %% [markdown]
# **Column - Versicolor & Virginica**

# %%
versicolor = data[data['species'] == 'versicolor']
virginica = data[data['species'] == 'virginica']

# %%
setosa_petal_length = setosa['petal_length']
virginica_petal_length = virginica['petal_length']

# %%
t_stat, p_value = stats.ttest_ind(setosa_petal_length, virginica_petal_length)
print("T Statistics :", t_stat)
print("P_Value :", p_value)
# Out:
# T Statistics : -49.98618625709594
# P_Value : 1.5048006992427275e-71

# %%
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in petal lengths between setosa and versicolor plants.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in petal lengths between setosa and versicolor plants.")
# Out:
# Reject the null hypothesis. There is a significant difference in petal lengths between setosa and versicolor plants.
